# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ragha\Downloads\OIBSIP_Data_Analytics_Task1_Retail_Sales.csv")

df.head()
# Out:
#   Transaction_ID        Date Customer_ID  Gender   Age Product_Category  \
# 0          T0001  2025-08-03        C431    Male  35.0           Beauty
# 1          T0002  2025-10-21        C486  Female  23.0   Home & Kitchen
# 2          T0003  2025-07-07        C371  Female  30.0      Electronics
# 3          T0004  2025-05-15        C121    Male  25.0           Beauty
# 4          T0005  2025-04-02        C467  Female  18.0      Electronics
#
#        Product  Quantity  Unit_Price  Total_Sales Payment_Method    City
# 0    Face Wash         2     1894.16      3788.32    Net Banking  Mumbai
# 1     Cookware         1     8858.59      8858.59           Cash    Pune
# 2   Smartwatch         2    10426.61     20853.22     Debit Card  Mumbai
# 3  Moisturizer         2     3467.77      6935.54    Credit Card  Mumbai
# 4   Smartwatch         1    20006.48     20006.48           Cash    Pune

# %%
df.shape
# Out:
# (1005, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    1005 non-null   object
#  1   Date              1005 non-null   object
#  2   Customer_ID       1005 non-null   object
#  3   Gender            1005 non-null   object
#  4   Age               1000 non-null   float64
#  5   Product_Category  1005 non-null   object
#  6   Product           1005 non-null   object
#  7   Quantity          1005 non-null   int64
#  8   Unit_Price        1005 non-null   float64
#  9   Total_Sales       1005 non-null   float64
#  10  Payment_Method    1000 non-null   object
#  11  City              1005 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 94.3+ KB

# %%
df.describe()
# Out:
#                Age     Quantity    Unit_Price    Total_Sales
# count  1000.000000  1005.000000   1005.000000    1005.000000
# mean     30.416000     2.179104   8877.173254   19747.652299
# std       8.990427     1.176531  13454.301313   36606.081077
# min      18.000000     1.000000     80.470000     141.630000
# 25%      23.000000     1.000000   1288.710000    2333.340000
# 50%      30.000000     2.000000   3198.810000    5893.300000
# 75%      36.000000     3.000000   8759.670000   17369.940000
# max      62.000000     5.000000  59972.240000  290541.200000

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of       Transaction_ID   Date  Customer_ID  Gender    Age  Product_Category  \
# 0              False  False        False   False  False             False
# 1              False  False        False   False  False             False
# 2              False  False        False   False  False             False
# 3              False  False        False   False  False             False
# 4              False  False        False   False  False             False
# ...              ...    ...          ...     ...    ...               ...
# 1000           False  False        False   False  False             False
# 1001           False  False        False   False  False             False
# 1002           False  False        False   False  False             False
# 1003           False  False        False   False  False             False
# 1004           False  False        False   False  False             False
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ragha\Downloads\OIBSIP_Data_Analytics_Task1_Retail_Sales.csv")

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Date                0
# Customer_ID         0
# Gender              0
# Age                 5
# Product_Category    0
# Product             0
# Quantity            0
# Unit_Price          0
# Total_Sales         0
# Payment_Method      5
# City                0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Payment_Method'] = df['Payment_Method'].fillna(df['Payment_Method'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Date                0
# Customer_ID         0
# Gender              0
# Age                 0
# Product_Category    0
# Product             0
# Quantity            0
# Unit_Price          0
# Total_Sales         0
# Payment_Method      0
# City                0
# dtype: int64

# %%
df.describe()
# Out:
#                Age     Quantity    Unit_Price    Total_Sales
# count  1000.000000  1000.000000   1000.000000    1000.000000
# mean     30.435000     2.182000   8876.905510   19785.948410
# std       8.975987     1.178246  13480.346052   36690.205582
# min      18.000000     1.000000     80.470000     141.630000
# 25%      23.000000     1.000000   1277.477500    2313.065000
# 50%      30.000000     2.000000   3173.670000    5881.100000
# 75%      36.000000     3.000000   8696.977500   17356.335000
# max      62.000000     5.000000  59972.240000  290541.200000

# %%
df['Total_Sales'].sum()
# Out:
# np.float64(19785948.41)

# %%
df['Total_Sales'].mean()
# Out:
# np.float64(19785.94841)

# %%
df['Quantity'].sum()
# Out:
# np.int64(2182)

# %%
import matplotlib.pyplot as plt

category_sales = df.groupby('Product_Category')['Total_Sales'].sum()

category_sales.plot(kind='bar')

plt.title('Total Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

daily_sales = df.groupby('Date')['Total_Sales'].sum()

daily_sales.plot(kind='line', figsize=(12, 5))

plt.title('Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %%
gender_sales = df.groupby('Gender')['Total_Sales'].sum()

gender_sales.plot(kind='bar')

plt.title('Total Sales by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Sales')
plt.xticks(rotation=0)
plt.show()

# %%
category_sales = df.groupby('Product_Category')['Total_Sales'].sum()
print(category_sales.sort_values(ascending=False))
# Out:
# Product_Category
# Electronics       14290715.26
# Home & Kitchen     2671041.93
# Clothing           1594768.43
# Beauty              910971.90
# Groceries           318450.89
# Name: Total_Sales, dtype: float64

# %%
product_sales = df.groupby('Product')['Total_Sales'].sum()
print(product_sales.sort_values(ascending=False).head(5))
# Out:
# Product
# Headphones    4415651.53
# Smartphone    3736620.76
# Smartwatch    3383519.84
# Laptop        2754923.13
# Blender        749040.32
# Name: Total_Sales, dtype: float64
